# %% [markdown]
# linear regression eqn is :
# y = mx + c
#
# y = b0*0   + b1*1 + E

# %%
 # Import necessary libraries
 import numpy as np 
 import pandas as pd 
 import matplotlib.pyplot as plt 
 import seaborn as sns

# %%
x = sm.add_constant(df["radio_spend"])
y = df["Sales"]

model = sm.OLS(y, sm.add_constant(x))

# %% [markdown]
# LINEM
# L - lINEARITY
# I - INDEPENDENCE
# N - NORMALITY
# E - EQUAL VARIANCES(HOMOSCEDASTICITY) = the spread of residuals should stay roughly constant across all fitted values. (Breusch-Pagan test)
# M - MULTICOLLINEARITY = reduce correlation

# %%
X = df['tv_spend']
y = df['sales']

x.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 X = df['tv_spend']
#       2 y = df['sales']
#       3
#       4 x.info()
#
# NameError: name 'df' is not defined

# %%
y.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 y.info()
#
# NameError: name 'y' is not defined

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,train_size=0.8, random_state=42)

x_train
x_test

# %%
plt.scatter(x,y)
plt.xlabel('Tv_spend')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# Statistical Inference For Linear Regression
#
# -> Standard Errors of coefficients.
# -> Confidence Intervals for coefficients.
# -> Hypothesis testing ---> t-test for individual coefficients.
# -> Overall model significance----> F-test
# -> R2 and Adjusted R2.
